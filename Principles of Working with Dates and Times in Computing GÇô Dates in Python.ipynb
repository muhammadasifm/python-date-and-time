# %%
import pandas as pd
#time stamp= time nd date
#standard time basline world wide(find based on avg solar time), each area have diffrent time nd date so utc is the ,subatract from utc,
#time zone= combine set of regulation indicating the local observed time for a fixed geographical region
#utc = standard
#gmt= time zone
#each time zone have diffrent restriction
#summer time =represent a system for extending the day light hourse during the conventional waking time in a perticular period of the year
#fall time =one hr back in fall
#for time series analysis(over viw the observation throught regular duration intervel), sales for specfic period of time, stock pricing, monthly analysis
# time is factor for dealing with logistic and international relatioship
#computer regulate time using unix time automatically
# countries can switch time zone for some reason, generally everyone follow one std
#unix time= keep the time running as sec, began recording on jan 1970 0 clock utc , called unix epoch also a time stamp
#time stamp represent in second so we have to convert ino date, time,sec
#general formate, ylmld,hlmls
#do integeration of time 
#need certain data type deal with date nd time
#datetime module

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'LoanID')
lending_co_data = data.copy()
lending_co_data.head()
#get df object
#look start type,seperated by /
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B         Female   Location 3  Region 2     17600.0
# 2       LoanID_2  Product D         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product B           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product A           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product B         Female  Location 34  Region 3     21250.0
#
#          StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1       04/07/2018     2200         45          365       3221       4166
# 2       02/01/2019     2200         45          365       3161       4096
# 3       08/12/2016     1000         45          365       2260       3205
# 4              NaN     2200         45          365       3141       4166
# 5       28/10/2017     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# ...

# %%
lending_co_data['StartDate'].head()
#pandas store the data type with undefined length as object
# Out:
# LoanID
# 1    04/07/2018
# 2    02/01/2019
# 3    08/12/2016
# 4           NaN
# 5    28/10/2017
# Name: StartDate, dtype: object

# %%
lending_co_data.info()
#string with undefined length
#get diffrent data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1043 entries, 1 to 1043
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StringID        1043 non-null   object
#  1   Product         1043 non-null   object
#  2   CustomerGender  1043 non-null   object
#  3   Location        1043 non-null   object
#  4   Region          1042 non-null   object
#  5   TotalPrice      1018 non-null   float64
#  6   StartDate       1042 non-null   object
#  7   Deposit         1043 non-null   int64
#  8   DailyRate       1043 non-null   int64
#  9   TotalDaysYr     1043 non-null   int64
#  10  AmtPaid36       1043 non-null   int64
#  11  AmtPaid60       1043 non-null   int64
#  12  AmtPaid360      1043 non-null   int64
#  13  LoanStatus      1006 non-null   object
# dtypes: float64(1), int64(6), object(7)
# memory usage: 122.2+ KB

# %%
lending_co_data['StartDate'].dtype
#data type of column
#datetime store as string as methord, 
#date nd time follow regulation,diffren from simple maths calculation, contain y,m,d,h,m,s,ms
#need module to orgaize this date nd time
# Out:
# dtype('O')

# %% [markdown]
# # date time module

# %%
from datetime import date
#have 6 classes date,delta, datetime,timedelta,tzinfo,time......, manipulate dates nd time as sprcific object

# %%
my_date=date(2021, 2, 20)
my_date
#pass argument throught date constructor(ctrate object of class and asign value it itself)
#date class dizply date y,m,d
#attribute of specfic instance of date class
#can use y,m,d as single component as attribute
# Out:
# datetime.date(2021, 2, 20)

# %%
type(my_date)
# my date object is instance of date class
# Out:
# datetime.date

# %%
print(my_date)
# Out:
# 2021-02-20

# %%
my_date.year
# Out:
# 2021

# %%
my_date.month
# Out:
# 2

# %%
my_date.day
#retrieved values are limited by thr conventional calender
#year range bw 1 to 9999
#mnoth 1 to 12, nd day within month
# Out:
# 20

# %%
my_date.weekday()
#not atribute so put ()
#monday =0
# Out:
# 5

# %%
date(2021, 3, 15) - date(2021, 2, 20)
#diffrent bw two date ,get the day, stored as date time object
# Out:
# datetime.timedelta(days=23)

# %%
# a better way to write it:
delta = date(2021, 3, 15) - date(2021, 2, 20)
delta.days
#days as atribute
#class for date module, time delta give diff bw two time
# subject from delta act as maths operation
# Out:
# 23

# %%
type(delta)
#automatic type conversion
# Out:
# datetime.timedelta

# %%
date(2021, 4, 22) + delta
#add 23
# Out:
# datetime.date(2021, 5, 15)

# %%
print(date(2021, 4, 22) + delta)
# Out:
# 2021-05-15

# %% [markdown]
# # time class

# %%
from datetime import time

# %%
local_time=time(hour=10, minute=30, second=15)
local_time
#take int argument and return datetime of object
#using time consructer pass the argument
#get instances of time argument
# Out:
# datetime.time(10, 30, 15)

# %%
local_time=time(10, 30, 15)
local_time
#dont pass argument
# Out:
# datetime.time(10, 30, 15)

# %%
type(local_time)
# Out:
# datetime.time

# %%
print(local_time)
# Out:
# 10:30:15

# %%
local_time.minute
# Out:
# 30

# %%
local_time.second
# Out:
# 15

# %%
local_time.microsecond
#this attribut not work, dont specfy argument value while constructing, default value is zero if dont pass argument,
#need to specfy 24 hr time convention,minut,sec
# Out:
# 0

# %%
local_time=time()
print(local_time)
# Out:
# 00:00:00

# %%
local_time=time(25)
print(local_time)
#morthan 23hr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/941989014.py in <module>
# ----> 1 local_time=time(25)
#       2 print(local_time)
#
# ValueError: hour must be in 0..23

# %%
local_time=time(23, 67, 100)
print(local_time)
#morthan 60 sec
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/1555028029.py in <module>
# ----> 1 local_time=time(23, 67, 100)
#       2 print(local_time)
#
# ValueError: minute must be in 0..59

# %% [markdown]
# # date time

# %%
#combine date nd time class

# %%
from datetime import datetime

# %%
my_datetime = datetime(year=2021, month=2, day=20,
hour=22, minute=30, second=12,
microsecond=500000)
my_datetime
#pass the argument as costructor of both date nd time class, need corect order
# Out:
# datetime.datetime(2021, 2, 20, 22, 30, 12, 500000)

# %%
# a quicker way to obtain the same output
my_datetime = datetime(2021, 2, 20,
22, 30, 12,
500000)
my_datetime
# can skip the parameter of argemnt
# Out:
# datetime.datetime(2021, 2, 20, 22, 30, 12, 500000)

# %%
print(my_datetime)
#makes various calculation
# Out:
# 2021-02-20 22:30:12.500000

# %%
# replacing some of the values of a datetime object nd work with new variable using replace methord
my_datetime = my_datetime.replace(minute=15, second=0)
print(my_datetime)
# Out:
# 2021-02-20 22:15:00.500000

# %% [markdown]
# # converting

# %% [markdown]
# # .strftime(): Converting datetime Objects into Strings

# %%
from datetime import date,datetime

# %%
my_datetime=datetime(2021, 2, 20)
my_datetime
# Out:
# datetime.datetime(2021, 2, 20, 0, 0)

# %%
#format code=combine operator plus letter charadisply a specfic date or  time componenrt
#case sensitive, look into the documentation
#designate the structure of current date

# %%
my_datetime.strftime('%Y')
# get year
# Out:
# '2021'

# %%
type(my_datetime.strftime('%Y'))
# Out:
# str

# %%
print(my_datetime.strftime('%Y'))
# Out:
# 2021

# %%
my_datetime.strftime('%d')
# Out:
# '20'

# %%
#using formate
my_datetime.strftime(' today is the day %d of month %n.')
# Out:
# ' today is the day 20 of month \n.'

# %%
#methord with instance of class
my_datetime=datetime(2021,2,20,22,30,12,500000)
my_datetime
# Out:
# datetime.datetime(2021, 2, 20, 22, 30, 12, 500000)

# %%
my_datetime.strftime(' it is %H hourse(s) , %M minute(s) ,and %S second(s) at the moment.')
# Out:
# ' it is 22 hourse(s) , 30 minute(s) ,and 12 second(s) at the moment.'

# %%
#date time module disply date time object, return specific format
#print date time as string
# format code disply specific element
#strtime return by order format code

# %% [markdown]
# # string into datetime

# %%
from datetime import datetime

# %%
string_datetime = '10:25:30 2021-02-20'
string_datetime
#text to datetime
#string pass time , only manipulate string
#date nd time
# Out:
# '10:25:30 2021-02-20'

# %%
type(string_datetime)
#triky while using maths operation
# Out:
# str

# %%
my_first_datetime = datetime.strptime(string_datetime, '%H:%M:%S %Y-%m-%d')
my_first_datetime
#see documentation , press tabe
#two argument, varable, need to specify  formate, order maariyalum python give date time value
# Out:
# datetime.datetime(2021, 2, 20, 10, 25, 30)

# %% [markdown]
# # other data type into datetime

# %%
import pandas as pd
#entire column from df to datetime

# %%
my_new_datetime = pd.to_datetime(string_datetime, format = '%H:%M:%S %Y-%m-%d')
my_new_datetime
#convert data tpe  str into datetime
#get std format op
# Out:
# Timestamp('2021-02-20 10:25:30')

# %%
type(my_new_datetime)
#time stamp object work  with pandas as date time in pythpon
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# without the "format" parameter:
my_new_datetime = pd.to_datetime(string_datetime)
my_new_datetime
# Out:
# Timestamp('2021-02-20 10:25:30')

# %%
my_new_datetime.hour
# Out:
# 10

# %%
my_new_datetime.minute
# Out:
# 25

# %%
my_new_datetime.second
# Out:
# 30

# %%
my_new_datetime.year
# Out:
# 2021

# %%
my_new_datetime.month
# Out:
# 2

# %%
my_new_datetime.day
# Out:
# 20

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'LoanID')
lending_co_data = data.copy()
lending_co_data.head()
#conver entire column
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B         Female   Location 3  Region 2     17600.0
# 2       LoanID_2  Product D         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product B           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product A           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product B         Female  Location 34  Region 3     21250.0
#
#          StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1       04/07/2018     2200         45          365       3221       4166
# 2       02/01/2019     2200         45          365       3161       4096
# 3       08/12/2016     1000         45          365       2260       3205
# 4              NaN     2200         45          365       3141       4166
# 5       28/10/2017     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# ...

# %%
# we are interested in 'StartDate'
lending_co_data['StartDate'].head()
#pandas str
# Out:
# LoanID
# 1    04/07/2018
# 2    02/01/2019
# 3    08/12/2016
# 4           NaN
# 5    28/10/2017
# Name: StartDate, dtype: object

# %%
pd.to_datetime(lending_co_data['StartDate'])
#converting , dont need formate, execute automaticlly
#datetime 64 pandas datetime representation,seperated with dashes, ns= nano sec
# Out:
# LoanID
# 1      2018-04-07
# 2      2019-02-01
# 3      2016-08-12
# 4             NaT
# 5      2017-10-28
#           ...
# 1039   2018-12-29
# 1040   2018-03-28
# 1041   2018-04-26
# 1042   2016-10-25
# 1043   2019-05-15
# Name: StartDate, Length: 1043, dtype: datetime64[ns]

# %%
lending_co_data['StartDate'] = pd.to_datetime(lending_co_data['StartDate'])
lending_co_data.head()
#replace
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B         Female   Location 3  Region 2     17600.0
# 2       LoanID_2  Product D         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product B           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product A           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product B         Female  Location 34  Region 3     21250.0
#
#         StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1      2018-04-07     2200         45          365       3221       4166
# 2      2019-02-01     2200         45          365       3161       4096
# 3      2016-08-12     1000         45          365       2260       3205
# 4             NaT     2200         45          365       3141       4166
# 5      2017-10-28     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# LoanID
# ...

# %% [markdown]
# # timestamp

# %%
from datetime import datetime
import pandas as pd
import numpy as np
#time stamp record of exact time
#unix time is generally use in computer, its number second pass from 1st jan 1970, representation called unit time stmp,need more readable way of this send

# %%
# to datetime
my_timestamp = 158215801.2000 # split sec into ms, int value
print(datetime.fromtimestamp(my_timestamp))
#unix time to usable formate
# Out:
# 1975-01-06 10:20:01.200000

# %%
# to UTC
print(datetime.utcfromtimestamp(my_timestamp))
#time stamb standarsized way of date nd time, must have zone regulation,time transformed into utc, can see
# Out:
# 1975-01-06 04:50:01.200000

# %%
my_new_datetime = datetime(2021, 2, 20,
22, 30, 12,
500000)
my_new_datetime
#generate timestamp from datevtime
# Out:
# datetime.datetime(2021, 2, 20, 22, 30, 12, 500000)

# %%
# to timestamp
my_new_datetime.timestamp()
# Out:
# 1613840412.5

# %%
current_time = datetime.now()
current_time
#get current time
# Out:
# datetime.datetime(2021, 11, 25, 0, 35, 58, 355832)

# %%
current_timestamp = datetime.timestamp(current_time)
current_timestamp
#current stamp
# Out:
# 1637780758.355832

# %%
current_datetime = datetime.fromtimestamp(current_timestamp)
current_datetime
#check
# Out:
# datetime.datetime(2021, 11, 25, 0, 35, 58, 355832)

# %%
# a pandas representation
pandas_timestamp = pd.Timestamp(datetime(2021, 1, 20, 18, 5))
pandas_timestamp
#pandas has its own time stamp, disply same as object in the class
# Out:
# Timestamp('2021-01-20 18:05:00')

# %%
# a NumPy representation
numpy_timestamp = np.datetime64('2021-01-20 18:05:00')
numpy_timestamp
#numpy form of datetime, use numpy computation
# Out:
# numpy.datetime64('2021-01-20T18:05:00')

# %% [markdown]
# # converting bw time zone

# %%
import pytz
from datetime import datetime
import pandas as pd
#time zone a set of regulation indicating the local observed time for fixed geographical reagion
#all time zone have offset from utc showing the diffrence bw universal time nd local time in yhat geographical reagion, this diffrence reveal howmny hours ahead or behind the universal time the local time is
#time stamp doesnt contan offset value
#pytz module extract diffrent time zone,
#have to install, not include in pythion

# %%
my_datetime = datetime(2021, 1, 14, 15, 30)
print(my_datetime)
#no time zone in every date time object that caled naive object
#date time object that inliude time zone date are know as aware object
#tzinfo to get time zone
# Out:
# 2021-01-14 15:30:00

# %%
my_datetime.tzinfo
#naive + .tzinfo= none
#didnt specify time zone information relate to date time object

# %%
print(my_datetime.tzinfo)
#object is naive object
# Out:
# None

# %%
my_timezone_info = datetime(2021, 1, 14, 15, 30, tzinfo = pytz.UTC)
print(my_timezone_info)
#aware object(datetime and pytz), give time cordinated universal time +time zone offset here its 00
#pytz deliver instant time zone information called olson time zone data base
#historical changes of local time regulation in diffrent location around the world
#regularly updating modification due to political reason  , maintain dataset in real time that reflect utc offset as well as day light saving rule
# Out:
# 2021-01-14 15:30:00+00:00

# %%
print(my_timezone_info.tzinfo)
#check
#convert the my time zone info bw diffrent time zones and observe the changes of its offset from utc
#use datetime.astimerzone() methord, carry on the conversion of specific datime value from its current time zone
# next methord is pytz.timezone() designate the time zone we are aiming to convert to
# Out:
# UTC

# %%
tz_US = my_timezone_info.astimezone(pytz.timezone('US/Central'))
print(tz_US)
# find the time zone of centrel us ,date time object converted , contain value and indication for an offset of 6 hr from utc
#can do for for all time zone that store in pytz
# Out:
# 2021-01-14 09:30:00-06:00

# %%
# show all the timezones
pytz.all_timezones
#all time zone supported by pytz
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %% [markdown]
# # conversion time zone in pandas

# %%
import pytz
from datetime import datetime
import pandas as pd

# %%
# Converting between Timezones with pandas
tz_US_pandas = pd.to_datetime(tz_US)
tz_US_pandas
#time stamp is python alternative of datetime object
#convert into pandas ng get utc nd time zone , ware object
# Out:
# Timestamp('2021-01-14 09:30:00-0600', tz='US/Central')

# %%
tz_UTC = tz_US_pandas.tz_convert('UTC')
print(tz_UTC)
#convert tz us back into utc, tz-convert
#its depend which one use
# Out:
# 2021-01-14 15:30:00+00:00

# %% [markdown]
# # Practical Example - Dates, Times, and Time Zones

# %% [markdown]
# # Main Task:
#
# Obtain information about the product sales of the various retailer types in UTC offset. Display the average amount of sales that occurred in each time zone.
#
# ##Solution map:
# ###Subtask 1:
# Store the date and time values in a single column called "MOS", denoting "Moment of Sale". Verify that the time zone values stored in "sales_data" are valid and can be manipulated with the pytz module. (Data Preparation)
# ###Subtask 2:
# Estimate the offset of the values of "MOS" to UTC. Store them in a column called "OffsetUTC". (Data Manipulation)
# ###Subtask 3:
# Order all sales according to a reconciled UTC-equivalent of the moment of sale and analyze the data. (Data Analysis)
# ###Subtask 4:
# Obtain statistics and visualizations that will respond to the Main Task and further improve the analysis of your data. (Data Visualization)'''

# %%
#analyze product sale
#express offset in utc
#examin values frome a dataset 
#set and manipulate these value according various regional application

# %%
import pandas as pd # manipulate time stamp
import pytz# work wih timezone,olson db, datetim feature 
from datetime import datetime # deal date nd time simultaniosly import date time class
from matplotlib import pyplot as plt # viz result
# install matplotlib and pytz
#look at the data
#contain date, time , timezone, product sales of globally operating time period, 100 lines, each line represent a specific sales, with uniq id,
#have momennt of sales
# arrange the date and time efficently to manipulate the data
#import neccesary library
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv('Sales-products-tz-mod.csv', index_col = 'SaleID')
sales_data = data.copy()
sales_data
#sales of data of that company
# Out:
#            RetailerCountry       RetailerType                    Product  \
# SaleID
# SaleID_1     United States      Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2     United States      Outdoors Shop     TrailChef Double Flame
# SaleID_3     United States      Outdoors Shop                  Star Dome
# SaleID_4     United States      Outdoors Shop               Star Gazer 2
# SaleID_5             Italy      Outdoors Shop       Canyon Mule Carryall
# ...                    ...                ...                        ...
# SaleID_96        Australia       Sports Store       Mountain Man Extreme
# SaleID_97        Australia   Department Store          Firefly Mapreader
# SaleID_98        Australia  Discount Retailer                  Polar Sun
# SaleID_99        Australia  Discount Retailer                  Polar Ice
# SaleID_100       Australia  Discount Retailer               Polar Sports
#
#             Sales Revenue ($)  DateOfSale TimeOfSale        TimeZone
# SaleID
# ...

# %%
sales_data[['DateOfSale', "TimeOfSale", "TimeZone"]].head()
# column we work with
# Out:
#           DateOfSale TimeOfSale TimeZone
# SaleID
# SaleID_1  06/01/2020   23:20:56      EST
# SaleID_2  05/02/2020   17:27:08      EST
# SaleID_3  30/10/2020   09:04:43      EST
# SaleID_4  13/11/2020   04:25:06      EST
# SaleID_5  06/12/2020   11:15:47      CET

# %% [markdown]
# # Part I - Data Preparation
# Subtask 1: Store the date and time values in a single column called 'MOS', denoting 'Moment of Sale'. Verify that the time zone values stored in "sales_data" are valid and can be manipulated with the pytz module. (Data Preparation)

# %%
date_and_time = sales_data['DateOfSale'] + " " + sales_data['TimeOfSale']
date_and_time 
#python maintain collection of library and modules that deal with problrms in diffrnt way
#re arrange dat set
# concatination
#sepet add " "
# Out:
# SaleID
# SaleID_1      06/01/2020 23:20:56
# SaleID_2      05/02/2020 17:27:08
# SaleID_3      30/10/2020 09:04:43
# SaleID_4      13/11/2020 04:25:06
# SaleID_5      06/12/2020 11:15:47
#                      ...
# SaleID_96     23/07/2019 12:30:03
# SaleID_97     03/01/2019 01:39:14
# SaleID_98     14/02/2019 21:29:35
# SaleID_99     19/06/2020 11:16:19
# SaleID_100    25/05/2019 15:51:41
# Length: 100, dtype: object

# %%
sales_data['MOS'] = pd.to_datetime(date_and_time)
sales_data.head()
#convert datime object and store new column called moment of sales
#insert sales data
#take part diffrent time relate and calculation n doperation
# Out:
#          RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1   United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2   United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3   United States  Outdoors Shop                  Star Dome
# SaleID_4   United States  Outdoors Shop               Star Gazer 2
# SaleID_5           Italy  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($)  DateOfSale TimeOfSale TimeZone  \
# SaleID
# SaleID_1              200.0  06/01/2020   23:20:56      EST
# SaleID_2                7.0  05/02/2020   17:27:08      EST
# SaleID_3               20.0  30/10/2020   09:04:43      EST
# SaleID_4               40.0  13/11/2020   04:25:06      EST
# SaleID_5              150.5  06/12/2020   11:15:47      CET
#
#                          MOS
# SaleID
# SaleID_1 2020-06-01 23:20:56
# SaleID_2 2020-05-02 17:27:08
# SaleID_3 2020-10-30 09:04:43
# SaleID_4 2020-11-13 04:25:06
# ...

# %%
sales_data = sales_data.drop(['DateOfSale','TimeOfSale'], axis = 1)
sales_data.head()
#drop the clumn date of sale and time sale bcz it include in mos, specify axes=1 since only remove column
#unnessary part
# Out:
#          RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1   United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2   United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3   United States  Outdoors Shop                  Star Dome
# SaleID_4   United States  Outdoors Shop               Star Gazer 2
# SaleID_5           Italy  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($) TimeZone                 MOS
# SaleID
# SaleID_1              200.0      EST 2020-06-01 23:20:56
# SaleID_2                7.0      EST 2020-05-02 17:27:08
# SaleID_3               20.0      EST 2020-10-30 09:04:43
# SaleID_4               40.0      EST 2020-11-13 04:25:06
# SaleID_5              150.5      CET 2020-06-12 11:15:47

# %%
pytz.all_timezones
# involve time zone information
#help utc adgesment
#time zone of diffrent region stored in python library
#name of region will be diffrent in python nd other article
#eet(eastern uropian time)=oez(other article)
#olson db , can do political modification,international restriction, utc offset, day light(dst) regulation
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
sales_data['TimeZone'].unique()
#compare the if the timezone indication from datset correspnds to list here
#which time zone can be encounterd our data set
#unique helps to find exclusive label listed within time zone column
# Out:
# array(['EST', 'CET', 'GMT', 'EET', 'SGT', 'Australia/West'], dtype=object)

# %%
for i in sales_data['TimeZone'].unique():
    if i in (pytz.all_timezones):
        print (True)
    else:
        print (False)
#verify this found ozon dataset
#false = not found in pytz module
# Out:
# True
# True
# True
# True
# False
# True

# %%
sales_data['TimeZone'].unique()
#quik check
# Out:
# array(['EST', 'CET', 'GMT', 'EET', 'SGT', 'Australia/West'], dtype=object)

# %%
sales_data.loc[:, 'TimeZone'] = sales_data.loc[:, 'TimeZone'].replace({'SGT': 'Singapore'})
#substitute exxisting sgt indication in the data set with the corresponding one frome the pytz list, sgt maatti singapore aakunnu
#loc = localization, replace =replace

# %%
sales_data['TimeZone'].unique()
#replace
# Out:
# array(['EST', 'CET', 'GMT', 'EET', 'Singapore', 'Australia/West'],
#       dtype=object)

# %%
for i in sales_data['TimeZone'].unique():
    if i in (pytz.all_timezones):
        print (True)
    else:
        print (False)
#verify
# Out:
# True
# True
# True
# True
# True
# True

# %%
sales_data[sales_data['TimeZone'] == 'Singapore']
#check in filtering of singapore
# Out:
#           RetailerCountry     RetailerType                Product  \
# SaleID
# SaleID_18       Singapore    Outdoors Shop         Granite Pulley
# SaleID_19       Singapore    Outdoors Shop  Firefly Climbing Lamp
# SaleID_20       Singapore    Outdoors Shop            Granite Ice
# SaleID_21       Singapore    Outdoors Shop    Mountain Man Analog
# SaleID_22       Singapore    Outdoors Shop   Mountain Man Digital
# SaleID_23       Singapore    Outdoors Shop    Mountain Man Deluxe
# SaleID_81       Singapore  Warehouse Store      EverGlow Kerosene
# SaleID_82       Singapore    Outdoors Shop                     TX
#
#            Sales Revenue ($)   TimeZone                 MOS
# SaleID
# SaleID_18              19.00  Singapore 2019-02-01 01:32:09
# SaleID_19              23.45  Singapore 2019-02-20 07:07:10
# SaleID_20              65.00  Singapore 2019-10-04 10:27:26
# SaleID_21              10.00  Singapore 2019-10-07 05:20:29
# ...

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None
sales_data
#see the modification
#no limit on number of disply of colmn nd rows
#can see the adjested dataset
# Out:
#            RetailerCountry       RetailerType                         Product  \
# SaleID
# SaleID_1     United States      Outdoors Shop       TrailChef Deluxe Cook Set
# SaleID_2     United States      Outdoors Shop          TrailChef Double Flame
# SaleID_3     United States      Outdoors Shop                       Star Dome
# SaleID_4     United States      Outdoors Shop                    Star Gazer 2
# SaleID_5             Italy      Outdoors Shop            Canyon Mule Carryall
# SaleID_6             Italy      Outdoors Shop                       Firefly 4
# SaleID_7    United Kingdom      Outdoors Shop                   Husky Rope 50
# SaleID_8    United Kingdom      Outdoors Shop           Granite Signal Mirror
# SaleID_9    United Kingdom      Outdoors Shop               Granite Carabiner
# SaleID_10            Italy      Outdoors Shop                    Granite Grip
# SaleID_11            Italy      Outdoors Shop                     Granite Axe
# ...

# %% [markdown]
# # Part II - Data Manipulation¶
# Subtask 2: Estimate the offset of the values of "MOS" to UTC. Store them in a column called "OffsetUTC". (Data Manipulation)

# %%
sales_data['MOS'].iloc[0]
#utc offset calculation nd store in seperate variable
#calculate utc of mos colun, 
#take single value to practice
# Out:
# Timestamp('2020-06-01 23:20:56')

# %%
sales_data['MOS'].iloc[0].tz_localize(sales_data['TimeZone'].iloc[0])
#verify, yes its pertcular object, a time stamp, pandas equvalent of python date time object
#time stamp get by construction  bcz
#create mos column with help of to datetime methored then obtain timezione indication assosiated with the given sales of the time zone clumn,, then trNsform object naive into aware, to acheive the goal
#using pandas tz.localize()
#designate value of intrest with iloc
#use aargument value from time zone column on the samw row zero
#get the date time object from utc and relevent time zone , est, represent the moment of this perticuar sales part in us.
#building clear time prespective of each sale
# Out:
# Timestamp('2020-06-01 23:20:56-0500', tz='EST')

# %%
list_mos_timestamps = []
list_mos_timestamps
#create time zone aware object for all records
#get offset value nd time zone of each record
#use to store new time stamp 
#iterate entire length of sale table
# append obtain time stamb value from every row list to  mos tmestamp
# Out:
# []

# %%
for i in range(len(sales_data)):
    list_mos_timestamps.append(pd.to_datetime(sales_data['MOS'].iloc[i].tz_localize(sales_data['TimeZone'].iloc[i], ambiguous='raise', nonexistent='raise')))
    # raise value obtain message indicating  if certain condition has not been met
    #

# %%
list_mos_timestamps[:10]
#verify by few value
#list slicing
#non ambique or non existing value value
# Out:
# [Timestamp('2020-06-01 23:20:56-0500', tz='EST'),
#  Timestamp('2020-05-02 17:27:08-0500', tz='EST'),
#  Timestamp('2020-10-30 09:04:43-0500', tz='EST'),
#  Timestamp('2020-11-13 04:25:06-0500', tz='EST'),
#  Timestamp('2020-06-12 11:15:47+0200', tz='CET'),
#  Timestamp('2020-07-06 01:54:41+0200', tz='CET'),
#  Timestamp('2020-12-27 02:07:28+0000', tz='GMT'),
#  Timestamp('2020-09-15 11:44:57+0000', tz='GMT'),
#  Timestamp('2020-09-23 01:40:29+0000', tz='GMT'),
#  Timestamp('2020-06-24 18:43:04+0200', tz='CET')]

# %%
list_mos_timestamps
#check entire list
#apply localization perfectly
#its possible obtain diffrent utc offset value for thesingle time zone
#look cet nd eet, cet can assosiated with 1 or 2 hr offset from utc, eet 2 or 3 hr offset, one hr distiction within each time ?
#one hr diffrence reflect the day light saving time. which isntbe te same during winter and summer time in the various time zone in the world
#pytz olson time zone db reflect the state in the dst regulation asosiated with the moment of executing the relevent cod cell
#diffrence cet nd eet is ordinary
# Out:
# [Timestamp('2020-06-01 23:20:56-0500', tz='EST'),
#  Timestamp('2020-05-02 17:27:08-0500', tz='EST'),
#  Timestamp('2020-10-30 09:04:43-0500', tz='EST'),
#  Timestamp('2020-11-13 04:25:06-0500', tz='EST'),
#  Timestamp('2020-06-12 11:15:47+0200', tz='CET'),
#  Timestamp('2020-07-06 01:54:41+0200', tz='CET'),
#  Timestamp('2020-12-27 02:07:28+0000', tz='GMT'),
#  Timestamp('2020-09-15 11:44:57+0000', tz='GMT'),
#  Timestamp('2020-09-23 01:40:29+0000', tz='GMT'),
#  Timestamp('2020-06-24 18:43:04+0200', tz='CET'),
#  Timestamp('2019-05-19 02:12:30+0200', tz='CET'),
#  Timestamp('2019-05-04 07:38:10-0500', tz='EST'),
#  Timestamp('2020-01-24 08:51:28-0500', tz='EST'),
#  Timestamp('2019-07-12 08:14:53-0500', tz='EST'),
#  Timestamp('2020-01-13 05:32:40-0500', tz='EST'),
#  Timestamp('2020-11-26 10:17:48+0200', tz='EET'),
#  Timestamp('2020-01-23 19:36:25+0200', tz='EET'),
#  Timestamp('2019-02-01 01:32:09+0800', tz='Singapore'),
#  Timestamp('2019-02-20 07:07:10+0800', tz='Singapore'),
# ...

# %%
list_mos_timestamps[0].strftime('%Y-%m-%d %H:%M:%S')
#more manipulation newly created list
# Out:
# '2020-06-01 23:20:56'

# %%
list_mos_timestamps[0].strftime('%z')
#seperate element from new list, using list and utc offset ans z
#- mean 5hr behind
# Out:
# '-0500'

# %%
float(list_mos_timestamps[0].strftime('%z'))/100
#into float and remove 00, numeric value for utc reprentation
# Out:
# -5.0

# %%
list_mos_timestamps[0].date()
#apply group of methords to deliver the same datetime value as instances of the date and time class quicker
#date recorded in the this list
# can work pandas date time object
# Out:
# datetime.date(2020, 6, 1)

# %%
list_mos_timestamps[0].time()
# Out:
# datetime.time(23, 20, 56)

# %%
list_mos_timestamps[0].utcoffset()
#offset of given value
#get instances of time delta class,consist of time of the day nd secc
# neg one day behind utc
# Out:
# datetime.timedelta(days=-1, seconds=68400)

# %%
list_mos_timestamps[0].utcoffset().total_seconds() / 3600
#60mints in hr nd 60 sec in each min so total sec in hr 3600
#to with total seconds to get offset
#breake down, 68400/3600= 19 ,-1 days, 10 of clock previous day mean 5 hr behind midnight of utc, get -5.0
# Out:
# -5.0

# %%
sales_data['OffsetUTC'] = [list_mos_timestamps[i].utcoffset().total_seconds() / 3600 for i in range(len(sales_data))]
sales_data.head()
#with list comprehension 
#utc offset contain offset valu of all records
# Out:
#          RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1   United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2   United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3   United States  Outdoors Shop                  Star Dome
# SaleID_4   United States  Outdoors Shop               Star Gazer 2
# SaleID_5           Italy  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($) TimeZone                 MOS  OffsetUTC
# SaleID
# SaleID_1              200.0      EST 2020-06-01 23:20:56       -5.0
# SaleID_2                7.0      EST 2020-05-02 17:27:08       -5.0
# SaleID_3               20.0      EST 2020-10-30 09:04:43       -5.0
# SaleID_4               40.0      EST 2020-11-13 04:25:06       -5.0
# SaleID_5              150.5      CET 2020-06-12 11:15:47        2.0

# %%
column_names_reordered = ['RetailerCountry', 'MOS', 'TimeZone', 'OffsetUTC', 'RetailerType', 'Product', 'Sales Revenue ($)']
sales_data = sales_data[column_names_reordered]
sales_data.head()
#copmare diffrent moment of sale with offset, re arrange column
# Out:
#          RetailerCountry                 MOS TimeZone  OffsetUTC  \
# SaleID
# SaleID_1   United States 2020-06-01 23:20:56      EST       -5.0
# SaleID_2   United States 2020-05-02 17:27:08      EST       -5.0
# SaleID_3   United States 2020-10-30 09:04:43      EST       -5.0
# SaleID_4   United States 2020-11-13 04:25:06      EST       -5.0
# SaleID_5           Italy 2020-06-12 11:15:47      CET        2.0
#
#            RetailerType                    Product  Sales Revenue ($)
# SaleID
# SaleID_1  Outdoors Shop  TrailChef Deluxe Cook Set              200.0
# SaleID_2  Outdoors Shop     TrailChef Double Flame                7.0
# SaleID_3  Outdoors Shop                  Star Dome               20.0
# SaleID_4  Outdoors Shop               Star Gazer 2               40.0
# SaleID_5  Outdoors Shop       Canyon Mule Carryall              150.5

# %%
sales_data.groupby(['TimeZone', 'OffsetUTC']).count()
#insert the column of dst in data set having the benefit of utc
#to obtain more than one offset assosiated value with single ime zone
# Out:
#                           RetailerCountry  MOS  RetailerType  Product  \
# TimeZone       OffsetUTC
# Australia/West  8.0                    17   17            17       17
# CET             1.0                     6    6             6        6
#                 2.0                    10   10            10       10
# EET             2.0                     4    4             4        4
#                 3.0                     4    4             4        4
# EST            -5.0                    40   40            40       40
# GMT             0.0                    11   11            11       11
# Singapore       8.0                     8    8             8        8
#
#                           Sales Revenue ($)
# TimeZone       OffsetUTC
# Australia/West  8.0                      17
# CET             1.0                       6
#                 2.0                      10
# EET             2.0                       4
#                 3.0                       4
# ...

# %%
sales_data[sales_data['TimeZone']=='CET'].sort_values('OffsetUTC')
#filter obtain relevent values from time zone  and quostion nd arrange them by value of offset from utc
#perform for cet time zone
#get 1 nd 2 hr offset from universal time
#this diffrence is result of the dst specification related to various regiom and moment of sales
# Out:
#           RetailerCountry                 MOS TimeZone  OffsetUTC  \
# SaleID
# SaleID_31         Germany 2019-02-24 19:16:17      CET        1.0
# SaleID_73     Switzerland 2019-03-26 09:52:36      CET        1.0
# SaleID_74     Switzerland 2020-03-07 14:17:34      CET        1.0
# SaleID_75     Switzerland 2019-03-14 22:25:10      CET        1.0
# SaleID_77         Austria 2020-11-05 13:06:45      CET        1.0
# SaleID_80         Austria 2020-12-05 05:30:58      CET        1.0
# SaleID_5            Italy 2020-06-12 11:15:47      CET        2.0
# SaleID_6            Italy 2020-07-06 01:54:41      CET        2.0
# SaleID_10           Italy 2020-06-24 18:43:04      CET        2.0
# SaleID_11           Italy 2019-05-19 02:12:30      CET        2.0
# SaleID_30         Germany 2019-05-21 14:03:10      CET        2.0
# SaleID_72     Switzerland 2019-05-30 06:36:09      CET        2.0
# SaleID_76     Switzerland 2020-04-06 12:36:06      CET        2.0
# ...

# %% [markdown]
# # Part III - Data Analysis

# %% [markdown]
# # Subtask 3: Order all sales according to a reconciled UTC-equivalent of the moment of sale and analyze the data. (Data Analysis)

# %%
sales_data.sort_values(['MOS'])
#previos we structured nd orderd data set to obtain more information nd well oorganized table
#get sorted valure based on time nd record
# Out:
#            RetailerCountry                 MOS        TimeZone  OffsetUTC  \
# SaleID
# SaleID_60           Canada 2019-01-02 23:10:36             EST       -5.0
# SaleID_33           Canada 2019-01-16 13:33:16             EST       -5.0
# SaleID_87        Australia 2019-01-19 04:29:44  Australia/West        8.0
# SaleID_18        Singapore 2019-02-01 01:32:09       Singapore        8.0
# SaleID_98        Australia 2019-02-14 21:29:35  Australia/West        8.0
# SaleID_19        Singapore 2019-02-20 07:07:10       Singapore        8.0
# SaleID_31          Germany 2019-02-24 19:16:17             CET        1.0
# SaleID_97        Australia 2019-03-01 01:39:14  Australia/West        8.0
# SaleID_53           Canada 2019-03-01 15:40:25             EST       -5.0
# SaleID_94        Australia 2019-03-03 22:51:15  Australia/West        8.0
# SaleID_75      Switzerland 2019-03-14 22:25:10             CET        1.0
# SaleID_44           Canada 2019-03-20 16:02:13             EST       -5.0
# ...

# %%
sales_data['MOS-UTC'] = [pd.to_datetime(sales_data['MOS'].iloc[i]).tz_localize(sales_data['TimeZone'].iloc[i]).tz_convert('UTC') 
                        for i in range(len(sales_data))]
#reconsile moment of sales with thier utc equivalent representation
#convert all the values into utc nd store the value in diffrent column, arrange them in chronological order , which sale happend first nd last
#use list comprehension, designate the value in mos utc,contain converted value
#then localize the value  from mos column, according to relevent time zone, nd use tz convert to adjest value by utc
#run throught all records sales data
# Out:
# C:\Users\Adil\AppData\Local\Temp/ipykernel_6980/1367813371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['MOS-UTC'] = [pd.to_datetime(sales_data['MOS'].iloc[i]).tz_localize(sales_data['TimeZone'].iloc[i]).tz_convert('UTC')

# %%
sales_data.head()
#column with mos convert to utc
# Out:
#          RetailerCountry                 MOS TimeZone  OffsetUTC  \
# SaleID
# SaleID_1   United States 2020-06-01 23:20:56      EST       -5.0
# SaleID_2   United States 2020-05-02 17:27:08      EST       -5.0
# SaleID_3   United States 2020-10-30 09:04:43      EST       -5.0
# SaleID_4   United States 2020-11-13 04:25:06      EST       -5.0
# SaleID_5           Italy 2020-06-12 11:15:47      CET        2.0
#
#            RetailerType                    Product  Sales Revenue ($)  \
# SaleID
# SaleID_1  Outdoors Shop  TrailChef Deluxe Cook Set              200.0
# SaleID_2  Outdoors Shop     TrailChef Double Flame                7.0
# SaleID_3  Outdoors Shop                  Star Dome               20.0
# SaleID_4  Outdoors Shop               Star Gazer 2               40.0
# SaleID_5  Outdoors Shop       Canyon Mule Carryall              150.5
#
#                            MOS-UTC
# SaleID
# SaleID_1 2020-06-02 04:20:56+00:00
# SaleID_2 2020-05-02 22:27:08+00:00
# ...

# %%
column_names_reordered = ['RetailerCountry', 'MOS-UTC', 'MOS', 'TimeZone', 'OffsetUTC', 'RetailerType', 'Product', 'Sales Revenue ($)']
sales_data = sales_data[column_names_reordered]
sales_data.head()
#sort according utc of mos nd re  order column, get which sale occure sooner nd later
# Out:
#          RetailerCountry                   MOS-UTC                 MOS  \
# SaleID
# SaleID_1   United States 2020-06-02 04:20:56+00:00 2020-06-01 23:20:56
# SaleID_2   United States 2020-05-02 22:27:08+00:00 2020-05-02 17:27:08
# SaleID_3   United States 2020-10-30 14:04:43+00:00 2020-10-30 09:04:43
# SaleID_4   United States 2020-11-13 09:25:06+00:00 2020-11-13 04:25:06
# SaleID_5           Italy 2020-06-12 09:15:47+00:00 2020-06-12 11:15:47
#
#          TimeZone  OffsetUTC   RetailerType                    Product  \
# SaleID
# SaleID_1      EST       -5.0  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2      EST       -5.0  Outdoors Shop     TrailChef Double Flame
# SaleID_3      EST       -5.0  Outdoors Shop                  Star Dome
# SaleID_4      EST       -5.0  Outdoors Shop               Star Gazer 2
# SaleID_5      CET        2.0  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($)
# SaleID
# SaleID_1              200.0
# ...

# %%
sales_data.sort_values(['MOS-UTC'])
#to get exact time in utc to compare
#see the time conversion bw two column
# Out:
#            RetailerCountry                   MOS-UTC                 MOS  \
# SaleID
# SaleID_60           Canada 2019-01-03 04:10:36+00:00 2019-01-02 23:10:36
# SaleID_33           Canada 2019-01-16 18:33:16+00:00 2019-01-16 13:33:16
# SaleID_87        Australia 2019-01-18 20:29:44+00:00 2019-01-19 04:29:44
# SaleID_18        Singapore 2019-01-31 17:32:09+00:00 2019-02-01 01:32:09
# SaleID_98        Australia 2019-02-14 13:29:35+00:00 2019-02-14 21:29:35
# SaleID_19        Singapore 2019-02-19 23:07:10+00:00 2019-02-20 07:07:10
# SaleID_31          Germany 2019-02-24 18:16:17+00:00 2019-02-24 19:16:17
# SaleID_97        Australia 2019-02-28 17:39:14+00:00 2019-03-01 01:39:14
# SaleID_53           Canada 2019-03-01 20:40:25+00:00 2019-03-01 15:40:25
# SaleID_94        Australia 2019-03-03 14:51:15+00:00 2019-03-03 22:51:15
# SaleID_75      Switzerland 2019-03-14 21:25:10+00:00 2019-03-14 22:25:10
# SaleID_44           Canada 2019-03-20 21:02:13+00:00 2019-03-20 16:02:13
# ...

# %%
sales_data.groupby('TimeZone').mean()
#group records values in the time zone column nd see what is the avg offset from utc for that grp
# get tome zone as index value nd avg offset value for each time zone as floating number nd mean sales revenue each time zone
#established that there could be offset frome utc diffrence in countries in the same time zone due to dst regulation, thats why get whole numbers as mean value for cet nd eet
#this float indicate that there is more offset value for cet nd eet
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# Australia/West      8.000         273.105882
# CET                 1.625         415.710000
# EET                 2.500         586.687500
# EST                -5.000         230.385500
# GMT                 0.000         115.137273
# Singapore           8.000          27.688750

# %%
sales_data.groupby('TimeZone').count()
#get howmany sales have occured in each time zone
#no missing data, no discrepency, table with identical value for each column for every record
#gmt nd eet have only 8 sales for given period of time, 
#avg sales in singapoor is 22 lesser than eet, 596/27=22
#product sold in eet is aprox 22 time more expensive than one sold in singpoor
#verify the quality opf data, request more data before concluding sales revenue diffrence
# Out:
#                 RetailerCountry  MOS-UTC  MOS  OffsetUTC  RetailerType  \
# TimeZone
# Australia/West               17       17   17         17            17
# CET                          16       16   16         16            16
# EET                           8        8    8          8             8
# EST                          40       40   40         40            40
# GMT                          11       11   11         11            11
# Singapore                     8        8    8          8             8
#
#                 Product  Sales Revenue ($)
# TimeZone
# Australia/West       17                 17
# CET                  16                 16
# EET                   8                  8
# EST                  40                 40
# GMT                  11                 11
# Singapore             8                  8

# %%
sales_data.groupby(['TimeZone', 'OffsetUTC']).count()
#group by two colmn,
#dont get decimal bcz are in two diff column
# Out:
#                           RetailerCountry  MOS-UTC  MOS  RetailerType  \
# TimeZone       OffsetUTC
# Australia/West  8.0                    17       17   17            17
# CET             1.0                     6        6    6             6
#                 2.0                    10       10   10            10
# EET             2.0                     4        4    4             4
#                 3.0                     4        4    4             4
# EST            -5.0                    40       40   40            40
# GMT             0.0                    11       11   11            11
# Singapore       8.0                     8        8    8             8
#
#                           Product  Sales Revenue ($)
# TimeZone       OffsetUTC
# Australia/West  8.0            17                 17
# CET             1.0             6                  6
#                 2.0            10                 10
# EET             2.0             4                  4
# ...

# %%
sales_data.groupby('TimeZone').count().sort_values('Product', ascending = False)
#chaining sort value,
# the op all sales grouped by time zone from the one with the highest number of sales to one with lowest
# get time zones order by the asoosiated total number of sales in acending order
# Out:
#                 RetailerCountry  MOS-UTC  MOS  OffsetUTC  RetailerType  \
# TimeZone
# EST                          40       40   40         40            40
# Australia/West               17       17   17         17            17
# CET                          16       16   16         16            16
# GMT                          11       11   11         11            11
# EET                           8        8    8          8             8
# Singapore                     8        8    8          8             8
#
#                 Product  Sales Revenue ($)
# TimeZone
# EST                  40                 40
# Australia/West       17                 17
# CET                  16                 16
# GMT                  11                 11
# EET                   8                  8
# Singapore             8                  8

# %% [markdown]
# # Part IV - Data Visualization

# %% [markdown]
# Subtask 4: Obtain statistics and visualizations that will respond to the Main Task and further improve the analysis of yout data. (Data Visualization)

# %%
sales_data.head()
#current state
# Out:
#          RetailerCountry                   MOS-UTC                 MOS  \
# SaleID
# SaleID_1   United States 2020-06-02 04:20:56+00:00 2020-06-01 23:20:56
# SaleID_2   United States 2020-05-02 22:27:08+00:00 2020-05-02 17:27:08
# SaleID_3   United States 2020-10-30 14:04:43+00:00 2020-10-30 09:04:43
# SaleID_4   United States 2020-11-13 09:25:06+00:00 2020-11-13 04:25:06
# SaleID_5           Italy 2020-06-12 09:15:47+00:00 2020-06-12 11:15:47
#
#          TimeZone  OffsetUTC   RetailerType                    Product  \
# SaleID
# SaleID_1      EST       -5.0  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2      EST       -5.0  Outdoors Shop     TrailChef Double Flame
# SaleID_3      EST       -5.0  Outdoors Shop                  Star Dome
# SaleID_4      EST       -5.0  Outdoors Shop               Star Gazer 2
# SaleID_5      CET        2.0  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($)
# SaleID
# SaleID_1              200.0
# ...

# %%
sales_data_viz = sales_data.reset_index()
sales_data_viz.head()
#sale id reset with indfex methord get deafult int index
#order record chronologically, wont use sale id column as index, utc adjestested mos is usful, help plot data with time line
# Out:
#      SaleID RetailerCountry                   MOS-UTC                 MOS  \
# 0  SaleID_1   United States 2020-06-02 04:20:56+00:00 2020-06-01 23:20:56
# 1  SaleID_2   United States 2020-05-02 22:27:08+00:00 2020-05-02 17:27:08
# 2  SaleID_3   United States 2020-10-30 14:04:43+00:00 2020-10-30 09:04:43
# 3  SaleID_4   United States 2020-11-13 09:25:06+00:00 2020-11-13 04:25:06
# 4  SaleID_5           Italy 2020-06-12 09:15:47+00:00 2020-06-12 11:15:47
#
#   TimeZone  OffsetUTC   RetailerType                    Product  \
# 0      EST       -5.0  Outdoors Shop  TrailChef Deluxe Cook Set
# 1      EST       -5.0  Outdoors Shop     TrailChef Double Flame
# 2      EST       -5.0  Outdoors Shop                  Star Dome
# 3      EST       -5.0  Outdoors Shop               Star Gazer 2
# 4      CET        2.0  Outdoors Shop       Canyon Mule Carryall
#
#    Sales Revenue ($)
# 0              200.0
# 1                7.0
# 2               20.0
# 3               40.0
# 4              150.5

# %%
sales_data_viz = sales_data_viz.set_index('MOS-UTC').sort_index()
sales_data_viz.head()
#apply this index to mos utc nd sort them nd will arrange the rows from table sorting them accordingly throught the moment of sales in utc
# Out:
#                               SaleID RetailerCountry                 MOS  \
# MOS-UTC
# 2019-01-03 04:10:36+00:00  SaleID_60          Canada 2019-01-02 23:10:36
# 2019-01-16 18:33:16+00:00  SaleID_33          Canada 2019-01-16 13:33:16
# 2019-01-18 20:29:44+00:00  SaleID_87       Australia 2019-01-19 04:29:44
# 2019-01-31 17:32:09+00:00  SaleID_18       Singapore 2019-02-01 01:32:09
# 2019-02-14 13:29:35+00:00  SaleID_98       Australia 2019-02-14 21:29:35
#
#                                  TimeZone  OffsetUTC       RetailerType  \
# MOS-UTC
# 2019-01-03 04:10:36+00:00             EST       -5.0      Outdoors Shop
# 2019-01-16 18:33:16+00:00             EST       -5.0      Outdoors Shop
# 2019-01-18 20:29:44+00:00  Australia/West        8.0       Sports Store
# 2019-01-31 17:32:09+00:00       Singapore        8.0      Outdoors Shop
# 2019-02-14 13:29:35+00:00  Australia/West        8.0  Discount Retailer
#
#                                   Product  Sales Revenue ($)
# MOS-UTC
# ...

# %%
sales_data_viz['OffsetUTC'].plot(figsize=(10, 6))
#size og graph
#disply offset utc value along time line, order the offset from utc value this way illustrat the diversity of time zone which sales took part,
#not show actual time line relation
# Out:
# <AxesSubplot:xlabel='MOS-UTC'>

# %%
plt.scatter(sales_data_viz['OffsetUTC'], sales_data_viz['RetailerType'])
#display the type of retyler sshop selling company product in diffrent time zones zround the globe
#online retailer are only succesful in urop, where gmt and time zone thst are one nd two hr ahead apply.
# no warehouse nd mall sales are registerd in gmt(0) nd discount retailer
#make inference about all retailer type in various zones

# %%
sales_data_viz.groupby('TimeZone').sum()
#see the importance of hoe treat the offset from utc value in this cell
#bar chart disply how the sales amounts diffre in the various tim e zone
#offset value is numeric so matplot lib unable to plot the retailer shop data on time zone names bcz name are stored in strn 
#need numeric representation, can use values from offset utc column
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# Australia/West      136.0            4642.80
# CET                  26.0            6651.36
# EET                  20.0            4693.50
# EST                -200.0            9215.42
# GMT                   0.0            1266.51
# Singapore            64.0             221.51

# %%
total_sales_revenue_by_time_zone = sales_data_viz.groupby('TimeZone').sum()
total_sales_revenue_by_time_zone
# bar chart show how sales amount differe in the various time zone
#orgaize the data 
#group it by time zone and sum of all individual sales that registerd there
##chain groupby nd sum methord
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# Australia/West      136.0            4642.80
# CET                  26.0            6651.36
# EET                  20.0            4693.50
# EST                -200.0            9215.42
# GMT                   0.0            1266.51
# Singapore            64.0             221.51

# %%
plt.bar(total_sales_revenue_by_time_zone.index, # x asis is index valu
        height = total_sales_revenue_by_time_zone['Sales Revenue ($)']) # y axis, total sales revenue
#op give infoorm about the total sales each time zone in dataset
#store in new varable
#replicate the same chart to obtain avg as opposed to total sales
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize = (7, 6)) 

plt.bar(total_sales_revenue_by_time_zone.index, 
        height = total_sales_revenue_by_time_zone['Sales Revenue ($)'], 
        color = "#108A99") 

plt.xticks(rotation = 45, fontsize = 13) 
plt.yticks(fontsize = 13) 
plt.title("Total Sales Revenue by Time Zone", fontsize = 18, fontweight = "bold") 
plt.ylabel("Sales Revenue ($)", fontsize = 13 ) 

plt.show() 
##replicate the same chart to obtain avg as opposed to total sales

# %%
sales_data_viz.groupby(['TimeZone','OffsetUTC']).mean()
#replicatep the same chart to obtain avg as opposed to total sales
#wont give where most sale occure, give idea how much an avg customer spend in the company shop in the relevent time zone
# Out:
#                           Sales Revenue ($)
# TimeZone       OffsetUTC
# Australia/West  8.0              273.105882
# CET             1.0              651.453333
#                 2.0              274.264000
# EET             2.0              223.125000
#                 3.0              950.250000
# EST            -5.0              230.385500
# GMT             0.0              115.137273
# Singapore       8.0               27.688750

# %%
sales_data_viz.groupby(['TimeZone']).mean()
# avg by time zone
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# Australia/West      8.000         273.105882
# CET                 1.625         415.710000
# EET                 2.500         586.687500
# EST                -5.000         230.385500
# GMT                 0.000         115.137273
# Singapore           8.000          27.688750

# %%
sales_data_viz.groupby('TimeZone').mean().sort_values('Sales Revenue ($)')
#see ho prices vary acording to time zone diffrence and offset from utc value
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# Singapore           8.000          27.688750
# GMT                 0.000         115.137273
# EST                -5.000         230.385500
# Australia/West      8.000         273.105882
# CET                 1.625         415.710000
# EET                 2.500         586.687500

# %%
averages_by_time_zone = sales_data_viz.groupby('TimeZone').mean().sort_values('Sales Revenue ($)', ascending = False)
averages_by_time_zone
#dont need above result so remove frome group list nd observe value in the offset utc column
#conclude that they are quit distinctive
#order the value according to sales revenu
#apply sort value methord
#time zone from dataset orderd by the avg sales revenue value nd store in variable , litterally duplicate code weuse ealier
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# EET                 2.500         586.687500
# CET                 1.625         415.710000
# Australia/West      8.000         273.105882
# EST                -5.000         230.385500
# GMT                 0.000         115.137273
# Singapore           8.000          27.688750

# %%
plt.bar(averages_by_time_zone.index, 
        height = averages_by_time_zone['Sales Revenue ($)'])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize = (7, 6))

plt.bar(averages_by_time_zone.index, 
        height = averages_by_time_zone['Sales Revenue ($)'], 
        color = ["green", "blue", "red", "darkblue", "yellow", "purple"]) 

plt.xticks(rotation = 45, fontsize = 13) 
plt.yticks(fontsize = 13) 
plt.title("Average Sales per Time Zone", fontsize = 18, fontweight = "bold") 
plt.ylabel("Average Price in USD ($)", fontsize = 13 ) 

plt.show()
